# %%
import json
import sqlite3
import pandas as pd
import os

# %%
class SpiderDataset:
    def __init__(self, dataset_path):
        self.dataset_path = dataset_path
        self.train_data = self.load_json('train_spider.json')
        self.dev_data = self.load_json('dev.json')
        self.schema_data = self.load_json('tables.json')

    def load_json(self, filename):
        with open(os.path.join(self.dataset_path, filename), 'r') as file:
            return json.load(file)

    def get_schema_by_db_id(self, db_id):
        for schema in self.schema_data:
            if schema['db_id'] == db_id:
                return schema
        return None

    def get_db_path(self, db_id):
        return os.path.join(self.dataset_path, 'database', db_id, f'{db_id}.sqlite')

    def execute_query(self, db_id, query):
        db_path = self.get_db_path(db_id)
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()
        try:
            cursor.execute(query)
            result = cursor.fetchall()
            columns = [desc[0] for desc in cursor.description]
            return pd.DataFrame(result, columns=columns)
        except sqlite3.Error as e:
            print(f"Execution error: {e}")
            return None
        finally:
            cursor.close()
            conn.close()

# %%
dataset = SpiderDataset('./dataset')

# Load a sample query from dev dataset
sample_query = dataset.train_data[1]
question = sample_query['question']
gold_sql = sample_query['query']
db_id = sample_query['db_id']
schema = dataset.get_schema_by_db_id(db_id)

print("Question:", question)
print("Gold SQL:", gold_sql)
print("Schema:", schema)

# Executing a query on the Spider sample DB
result_df = dataset.execute_query(db_id, gold_sql)
if result_df is not None:
    print(result_df.head())
else:
    print("Query execution failed.")

df_final = pd.DataFrame(columns=['gold', 'db_id'])
for i in range(100):
    sample_query = dataset.train_data[i]
    df_final.loc[i] = [sample_query['query'], sample_query['db_id']]

    
df_final
# Out:
# Question: List the name, born state and age of the heads of departments ordered by age.
# Gold SQL: SELECT name ,  born_state ,  age FROM head ORDER BY age
# Schema: {'column_names': [[-1, '*'], [0, 'department id'], [0, 'name'], [0, 'creation'], [0, 'ranking'], [0, 'budget in billions'], [0, 'num employees'], [1, 'head id'], [1, 'name'], [1, 'born state'], [1, 'age'], [2, 'department id'], [2, 'head id'], [2, 'temporary acting']], 'column_names_original': [[-1, '*'], [0, 'Department_ID'], [0, 'Name'], [0, 'Creation'], [0, 'Ranking'], [0, 'Budget_in_Billions'], [0, 'Num_Employees'], [1, 'head_ID'], [1, 'name'], [1, 'born_state'], [1, 'age'], [2, 'department_ID'], [2, 'head_ID'], [2, 'temporary_acting']], 'column_types': ['text', 'number', 'text', 'text', 'number', 'number', 'number', 'number', 'text', 'text', 'number', 'number', 'number', 'text'], 'db_id': 'department_management', 'foreign_keys': [[12, 7], [11, 1]], 'primary_keys': [1, 7, 11], 'table_names': ['department', 'head', 'management'], 'table_names_original': ['department', 'head', 'management']}
#                  name   born_state   age
# 0  Pádraig Harrington  Connecticut  43.0
# 1        Stewart Cink      Florida  50.0
# 2         Dudley Hart   California  52.0
# 3        Jeff Maggert     Delaware  53.0
# 4          Nick Faldo   California  56.0
#                                                  gold                  db_id
# 0          SELECT count(*) FROM head WHERE age  >  56  department_management
# 1   SELECT name ,  born_state ,  age FROM head ORD...  department_management
# 2   SELECT creation ,  name ,  budget_in_billions ...  department_management
# 3   SELECT max(budget_in_billions) ,  min(budget_i...  department_management
# 4   SELECT avg(num_employees) FROM department WHER...  department_management
# ..                                                ...                    ...
# 95  SELECT course_name FROM courses ORDER BY cours...     student_assessment
# 96  SELECT course_name FROM courses ORDER BY cours...     student_assessment
# 97  SELECT first_name FROM people ORDER BY first_name     student_assessment
# 98  SELECT first_name FROM people ORDER BY first_name     student_assessment
# 99  SELECT student_id FROM student_course_registra...     student_assessment
#
# [100 rows x 2 columns]

# %%
df_final.to_csv("gold.tsv", sep='\t', index=False, header=False)

# %%
df5 = pd.read_csv("gold.csv")
df5
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df5 = pd.read_csv("gold.csv")
#       2 df5
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:843, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:904, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2058, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 3 fields in line 3, saw 5

# %%
df2 = pd.read_csv("text2sql_results_fewshot.csv")
#df1 = pd.read_csv("control_results.csv")
#df2 = df2.iloc[2:]
#df2 = df2.reset_index(drop=True)
df2
# Out:
#     query_id                                           question  \
# 0          0  How many heads of the departments are older th...
# 1          1  List the name, born state and age of the heads...
# 2          2  List the creation year, name and budget of eac...
# 3          3  What are the maximum and minimum budget of the...
# 4          4  What is the average number of employees of the...
# 5          5  What are the names of the heads who are born o...
# 6          6  What are the distinct creation years of the de...
# 7          7  What are the names of the states where at leas...
# 8          8   In which year were most departments established?
# 9          9  Show the name and number of employees for the ...
# 10        10                How many acting statuses are there?
# 11        11  How many departments are led by heads who are ...
# 12        12  What are the distinct ages of the heads who ar...
# 13        13  List the states where both the secretary of 'T...
# 14        14  Which department has more than 1 head at a tim...
# 15        15  Which head's name has the substring 'Ha'? List...
# 16        16                          How many farms are there?
# 17        17                         Count the number of farms.
# 18        18  List the total number of horses on farms in as...
# 19        19  What is the total horses record for each farm,...
# 20        20  What are the hosts of competitions whose theme...
# 21        21  Return the hosts of competitions for which the...
# 22        22  What are the themes of farm competitions sorte...
# 23        23  Return the themes of farm competitions, sorted...
# 24        24  What is the average number of working horses o...
# 25        25  Give the average number of working horses on f...
# 26        26  What are the maximum and minimum number of cow...
# 27        27  Return the maximum and minimum number of cows ...
# 28        28        How many different statuses do cities have?
# 29        29            Count the number of different statuses.
#
#                                                schema  \
# 0   {'column_names': [[-1, '*'], [0, 'department i...
# 1   {'column_names': [[-1, '*'], [0, 'department i...
# 2   {'column_names': [[-1, '*'], [0, 'department i...
# 3   {'column_names': [[-1, '*'], [0, 'department i...
# 4   {'column_names': [[-1, '*'], [0, 'department i...
# 5   {'column_names': [[-1, '*'], [0, 'department i...
# 6   {'column_names': [[-1, '*'], [0, 'department i...
# 7   {'column_names': [[-1, '*'], [0, 'department i...
# 8   {'column_names': [[-1, '*'], [0, 'department i...
# 9   {'column_names': [[-1, '*'], [0, 'department i...
# 10  {'column_names': [[-1, '*'], [0, 'department i...
# 11  {'column_names': [[-1, '*'], [0, 'department i...
# 12  {'column_names': [[-1, '*'], [0, 'department i...
# 13  {'column_names': [[-1, '*'], [0, 'department i...
# 14  {'column_names': [[-1, '*'], [0, 'department i...
# 15  {'column_names': [[-1, '*'], [0, 'department i...
# 16  {'column_names': [[-1, '*'], [0, 'city id'], [...
# 17  {'column_names': [[-1, '*'], [0, 'city id'], [...
# 18  {'column_names': [[-1, '*'], [0, 'city id'], [...
# 19  {'column_names': [[-1, '*'], [0, 'city id'], [...
# 20  {'column_names': [[-1, '*'], [0, 'city id'], [...
# 21  {'column_names': [[-1, '*'], [0, 'city id'], [...
# 22  {'column_names': [[-1, '*'], [0, 'city id'], [...
# 23  {'column_names': [[-1, '*'], [0, 'city id'], [...
# 24  {'column_names': [[-1, '*'], [0, 'city id'], [...
# 25  {'column_names': [[-1, '*'], [0, 'city id'], [...
# 26  {'column_names': [[-1, '*'], [0, 'city id'], [...
# 27  {'column_names': [[-1, '*'], [0, 'city id'], [...
# 28  {'column_names': [[-1, '*'], [0, 'city id'], [...
# 29  {'column_names': [[-1, '*'], [0, 'city id'], [...
#
#                                        agent_1_output  \
# 0    Tables - head; Columns - age; Ambiguities - None
# 1   Tables - head, management; Columns - name, bor...
# 2   Tables - department; Columns - creation, name,...
# 3   Tables - department; Columns - budget in billi...
# 4   Tables - department; Columns - num employees, ...
# 5   Tables - head; Columns - name, born state; Amb...
# 6   Tables - department, head, management; Columns...
# 7   Tables - head; Columns - born_state; Ambiguiti...
# 8   Tables - department; Columns - creation; Ambig...
# 9   Tables - department, head, management; Columns...
# 10  Tables - management; Columns - temporary actin...
# 11  Tables - department, head, management; Columns...
# 12  Tables - head, management; Columns - age, temp...
# 13  Tables - department, head, management; Columns...
# 14  Tables - department, head, management; Columns...
# 15  Tables - head; Columns - head id, name; Ambigu...
# 16  Tables - farm; Columns - farm id; Ambiguities ...
# 17  Tables - farm; Columns - farm id; Ambiguities ...
# 18  Tables - farm; Columns - total horses; Ambigui...
# 19  Tables - farm; Columns - farm id, total horses...
# 20  Tables - farm competition; Columns - hosts, th...
# 21  Tables - farm competition; Columns - hosts, th...
# 22  Tables - farm competition; Columns - theme, ye...
# 23  Tables - farm competition; Columns - theme, ye...
# 24  Tables - farm; Columns - total horses, working...
# 25  Tables - farm; Columns - total horses, working...
# 26  Tables - farm; Columns - cows; Ambiguities - None
# 27  Tables - farm; Columns - cows; Ambiguities - None
# 28  Tables - city; Columns - status; Ambiguities -...
# 29  Tables - city; Columns - status; Ambiguities -...
#
#                                        agent_2_output  \
# 0           SELECT COUNT(*) FROM head WHERE age > 56;
# 1   SELECT head.name, head.born_state, head.age FR...
# 2   SELECT creation, name, budget in billions FROM...
# 3   SELECT MAX(`budget in billions`), MIN(`budget ...
# 4   SELECT AVG(`num employees`) FROM department WH...
# 5   SELECT name FROM head WHERE born_state != 'Cal...
# 6   SELECT DISTINCT department.creation \nFROM dep...
# 7   SELECT born_state FROM head GROUP BY born_stat...
# 8   SELECT creation, COUNT(*) FROM department GROU...
# 9   SELECT department.name, department.num employe...
# 10                   SELECT COUNT(*) FROM management;
# 11  SELECT COUNT(*) FROM department WHERE departme...
# 12  SELECT DISTINCT head.age FROM head JOIN manage...
# 13  SELECT h.born_state \nFROM department d \nJOIN...
# 14  SELECT department.id, department.name, COUNT(m...
# 15  SELECT head.id, head.name FROM head WHERE head...
# 16                          SELECT COUNT(*) FROM farm
# 17                          SELECT COUNT(*) FROM farm
# 18  SELECT `total horses` FROM farm ORDER BY `tota...
# 19  SELECT `farm id`, SUM(`total horses`) FROM far...
# 20  SELECT hosts FROM farm_competition WHERE theme...
# 21  SELECT hosts FROM farm_competition WHERE theme...
# 22  SELECT theme, year FROM farm_competition ORDER...
# 23  SELECT theme FROM farm_competition ORDER BY ye...
# 24  SELECT AVG(working horses) FROM farm WHERE tot...
# 25  SELECT AVG(working horses) FROM farm WHERE tot...
# 26             SELECT MAX(cows), MIN(cows) FROM farm;
# 27              SELECT MAX(cows), MIN(cows) FROM farm
# 28           SELECT COUNT(DISTINCT status) FROM city;
# 29            SELECT COUNT(DISTINCT status) FROM city
#
#                                     agent_3a_output_1  \
# 0       The SQL query doesn't have any syntax issues.
# 1   The SQL query syntax is correct, there are no ...
# 2   Issue: The phrase "in billions" is not a valid...
# 3   The SQL query syntax appears to be correct, th...
# 4   There are no SQL syntax issues in the given qu...
# 5                    The SQL query syntax is correct.
# 6   The issue is with the space in the column name...
# 7   The SQL query syntax appears to be correct wit...
# 8   The SQL query syntax appears to be correct wit...
# 9   The issues in the SQL query are:\n\n1. The col...
# 10  The given SQL query "SELECT COUNT(*) FROM mana...
# 11  The issue is with the spacing in "department i...
# 12     The SQL query does not have any syntax issues.
# 13  The SQL query seems to have no syntax issues. ...
# 14  The SQL query appears to be correct with no sy...
# 15  The SQL query syntax appears to be correct, th...
# 16          The given SQL query has no syntax issues.
# 17      The SQL query doesn't have any syntax issues.
# 18  The SQL query syntax is correct, there are no ...
# 19     The SQL query does not have any syntax issues.
# 20     The SQL query does not have any syntax issues.
# 21     The SQL query does not have any syntax issues.
# 22  The given SQL query: SELECT theme, year FROM f...
# 23     The SQL query does not have any syntax issues.
# 24     The SQL query does not have any syntax issues.
# 25     The SQL query does not have any syntax issues.
# 26      The SQL query doesn't have any syntax issues.
# 27      The SQL query doesn't have any syntax issues.
# 28     The SQL query does not have any syntax issues.
# 29      The SQL query doesn't have any syntax issues.
#
#                                     agent_3b_output_1  \
# 0                                                  {}
# 1                                                  {}
# 2                                                  {}
# 3                                                  {}
# 4                                                  {}
# 5                                                  {}
# 6   {"department.department id": "department.depar...
# 7                                                  {}
# 8                                                  {}
# 9   {"department.num employees": "department.num_e...
# 10                                                 {}
# 11                 {"department id": "Department_ID"}
# 12                                                 {}
# 13  {"d.department id": "d.department_id", "m.depa...
# 14                                                 {}
# 15                                                 {}
# 16                                                 {}
# 17                                                 {}
# 18                                                 {}
# 19                                                 {}
# 20                                                 {}
# 21                                                 {}
# 22           {"farm_competition": "farm competition"}
# 23                                                 {}
# 24                                                 {}
# 25                                                 {}
# 26                                                 {}
# 27                                                 {}
# 28                                                 {}
# 29                                                 {}
#
#                                    execution_output_1  \
# 0                    (True,    COUNT(*)\n0         5)
# 1   (True,                  name   born_state   ag...
# 2                  (False, 'Query execution failed.')
# 3                  (False, 'Query execution failed.')
# 4                  (False, 'Query execution failed.')
# 5   (True,                  name\n0         Tiger ...
# 6                  (False, 'Query execution failed.')
# 7                (True,    born_state\n0  California)
# 8   (True,   Creation  COUNT(*)\n0     1789       ...
# 9                  (False, 'Query execution failed.')
# 10                   (True,    COUNT(*)\n0         5)
# 11                 (False, 'Query execution failed.')
# 12  (True, Empty DataFrame\nColumns: [age]\nIndex:...
# 13                 (False, 'Query execution failed.')
# 14                 (False, 'Query execution failed.')
# 15                 (False, 'Query execution failed.')
# 16                   (True,    COUNT(*)\n0         8)
# 17                   (True,    COUNT(*)\n0         8)
# 18                 (False, 'Query execution failed.')
# 19                 (False, 'Query execution failed.')
# 20  (True,                                   Hosts...
# 21  (True,                                   Hosts...
# 22  (True,                  Theme  Year\n0        ...
# 23  (True,                  Theme\n0              ...
# 24                 (False, 'Query execution failed.')
# 25                 (False, 'Query execution failed.')
# 26  (True,    MAX(cows)  MIN(cows)\n0     3987.0  ...
# 27  (True,    MAX(cows)  MIN(cows)\n0     3987.0  ...
# 28  (True,    COUNT(DISTINCT status)\n0           ...
# 29  (True,    COUNT(DISTINCT status)\n0           ...
#
#                                     agent_3c_output_1  \
# 0   SATISFACTORY SQL QUERY GENERATED\nSELECT COUNT...
# 1   SATISFACTORY SQL QUERY GENERATED\nSELECT head....
# 2   UNSATISFACTORY SQL QUERY GENERATED\n\nCorrecte...
# 3   SATISFACTORY SQL QUERY GENERATED\nSELECT MAX(`...
# 4   SATISFACTORY SQL QUERY GENERATED\n\nSELECT AVG...
# 5   SATISFACTORY SQL QUERY GENERATED\nSELECT name ...
# 6   UNSATISFACTORY SQL QUERY GENERATED\n\nSELECT D...
# 7   SATISFACTORY SQL QUERY GENERATED\nSELECT born_...
# 8   SATISFACTORY SQL QUERY GENERATED\n\nSELECT cre...
# 9   UNSATISFACTORY SQL QUERY GENERATED\n\nSELECT d...
# 10  SATISFACTORY SQL QUERY GENERATED\nSELECT COUNT...
# 11  UNSATISFACTORY SQL QUERY GENERATED\n\nSELECT C...
# 12  SATISFACTORY SQL QUERY GENERATED\nSELECT DISTI...
# 13  UNSATISFACTORY SQL QUERY GENERATED\n\nSELECT h...
# 14  UNSATISFACTORY SQL QUERY GENERATED\n\nSELECT d...
# 15  SATISFACTORY SQL QUERY GENERATED\nSELECT head....
# 16  SATISFACTORY SQL QUERY GENERATED\nSELECT COUNT...
# 17  SATISFACTORY SQL QUERY GENERATED\nSELECT COUNT...
# 18  SATISFACTORY SQL QUERY GENERATED\n\nSELECT `to...
# 19  SATISFACTORY SQL QUERY GENERATED\n\nSELECT `fa...
# 20  SATISFACTORY SQL QUERY GENERATED\nSELECT hosts...
# 21  SATISFACTORY SQL QUERY GENERATED\nSELECT hosts...
# 22  SATISFACTORY SQL QUERY GENERATED\nSELECT theme...
# 23  SATISFACTORY SQL QUERY GENERATED\nSELECT theme...
# 24  UNSATISFACTORY SQL QUERY GENERATED\nSELECT AVG...
# 25  UNSATISFACTORY SQL QUERY GENERATED\nSELECT AVG...
# 26  SATISFACTORY SQL QUERY GENERATED\nSELECT MAX(c...
# 27  SATISFACTORY SQL QUERY GENERATED\nSELECT MAX(c...
# 28  SATISFACTORY SQL QUERY GENERATED\nSELECT COUNT...
# 29  SATISFACTORY SQL QUERY GENERATED\nSELECT COUNT...
#
#                                     agent_3a_output_2 agent_3b_output_2  \
# 0                                                 NaN               NaN
# 1                                                 NaN               NaN
# 2   The given SQL query: SELECT creation, name, `b...                {}
# 3                                                 NaN               NaN
# 4                                                 NaN               NaN
# 5                                                 NaN               NaN
# 6      The SQL query does not have any syntax issues.                {}
# 7                                                 NaN               NaN
# 8                                                 NaN               NaN
# 9      The SQL query does not have any syntax issues.                {}
# 10                                                NaN               NaN
# 11     The SQL query does not have any syntax issues.                {}
# 12                                                NaN               NaN
# 13     The SQL query does not have any syntax issues.                {}
# 14  The SQL query appears to be syntactically corr...                {}
# 15                                                NaN               NaN
# 16                                                NaN               NaN
# 17                                                NaN               NaN
# 18                                                NaN               NaN
# 19                                                NaN               NaN
# 20                                                NaN               NaN
# 21                                                NaN               NaN
# 22                                                NaN               NaN
# 23                                                NaN               NaN
# 24     The SQL query does not have any syntax issues.                {}
# 25     The SQL query does not have any syntax issues.                {}
# 26                                                NaN               NaN
# 27                                                NaN               NaN
# 28                                                NaN               NaN
# 29                                                NaN               NaN
#
#                                    execution_output_2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                  (False, 'Query execution failed.')
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                      (True,   Creation\n0     1903)
# 7                                                 NaN
# 8                                                 NaN
# 9   (True,                 Name  Num_Employees\n0 ...
# 10                                                NaN
# 11                   (True,    COUNT(*)\n0        11)
# 12                                                NaN
# 13  (True,    born_state\n0    Delaware\n1  Califo...
# 14                 (False, 'Query execution failed.')
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  (True,    AVG(`Working_Horses`)\n0            ...
# 25  (True,    AVG(`Working_Horses`)\n0            ...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                     agent_3c_output_2  \
# 0                                                 NaN
# 1                                                 NaN
# 2   SATISFACTORY SQL QUERY GENERATED\nSELECT creat...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   SATISFACTORY SQL QUERY GENERATED\nSELECT DISTI...
# 7                                                 NaN
# 8                                                 NaN
# 9   SATISFACTORY SQL QUERY GENERATED\n\nSELECT dep...
# 10                                                NaN
# 11  SATISFACTORY SQL QUERY GENERATED\nSELECT COUNT...
# 12                                                NaN
# 13  SATISFACTORY SQL QUERY GENERATED\n\nSELECT h.b...
# 14  UNSATISFACTORY SQL QUERY GENERATED\n\nSELECT d...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24  SATISFACTORY SQL QUERY GENERATED\nSELECT AVG(`...
# 25  SATISFACTORY SQL QUERY GENERATED\nSELECT AVG(`...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                     agent_3a_output_3 agent_3b_output_3  \
# 0                                                 NaN               NaN
# 1                                                 NaN               NaN
# 2                                                 NaN               NaN
# 3                                                 NaN               NaN
# 4                                                 NaN               NaN
# 5                                                 NaN               NaN
# 6                                                 NaN               NaN
# 7                                                 NaN               NaN
# 8                                                 NaN               NaN
# 9                                                 NaN               NaN
# 10                                                NaN               NaN
# 11                                                NaN               NaN
# 12                                                NaN               NaN
# 13                                                NaN               NaN
# 14  The SQL query appears to be syntactically corr...                {}
# 15                                                NaN               NaN
# 16                                                NaN               NaN
# 17                                                NaN               NaN
# 18                                                NaN               NaN
# 19                                                NaN               NaN
# 20                                                NaN               NaN
# 21                                                NaN               NaN
# 22                                                NaN               NaN
# 23                                                NaN               NaN
# 24                                                NaN               NaN
# 25                                                NaN               NaN
# 26                                                NaN               NaN
# 27                                                NaN               NaN
# 28                                                NaN               NaN
# 29                                                NaN               NaN
#
#                     execution_output_3  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14  (False, 'Query execution failed.')
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                 NaN
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
# 28                                 NaN
# 29                                 NaN
#
#                                     agent_3c_output_3  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  UNSATISFACTORY SQL QUERY GENERATED\n\nSELECT d...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                           final_query
# 0           SELECT COUNT(*) FROM head WHERE age > 56;
# 1   SELECT head.name, head.born_state, head.age FR...
# 2   Corrected SQL Query: SELECT creation, name, `b...
# 3   SELECT MAX(`budget in billions`), MIN(`budget ...
# 4   SELECT AVG(`num employees`) FROM department WH...
# 5   SELECT name FROM head WHERE born_state != 'Cal...
# 6   SELECT DISTINCT department.creation \nFROM dep...
# 7   SELECT born_state FROM head GROUP BY born_stat...
# 8   SELECT creation, COUNT(*) FROM department GROU...
# 9   SELECT department.name, department.num_employe...
# 10                   SELECT COUNT(*) FROM management;
# 11  SELECT COUNT(*) FROM department WHERE departme...
# 12  SELECT DISTINCT head.age FROM head JOIN manage...
# 13  SELECT h.born_state \nFROM department d \nJOIN...
# 14  SELECT department.id, department.name, COUNT(m...
# 15  SELECT head.id, head.name FROM head WHERE head...
# 16                          SELECT COUNT(*) FROM farm
# 17                          SELECT COUNT(*) FROM farm
# 18  SELECT `total horses` FROM farm ORDER BY `tota...
# 19  SELECT `farm id`, SUM(`total horses`) FROM far...
# 20  SELECT hosts FROM farm_competition WHERE theme...
# 21  SELECT hosts FROM farm_competition WHERE theme...
# 22  SELECT theme, year FROM farm_competition ORDER...
# 23  SELECT theme FROM farm_competition ORDER BY ye...
# 24  SELECT AVG(`Working_Horses`) FROM farm WHERE `...
# 25  SELECT AVG(`Working_Horses`) FROM `farm` WHERE...
# 26             SELECT MAX(cows), MIN(cows) FROM farm;
# 27              SELECT MAX(cows), MIN(cows) FROM farm
# 28           SELECT COUNT(DISTINCT status) FROM city;
# 29            SELECT COUNT(DISTINCT status) FROM city

# %%
df_control = pd.DataFrame({
    'prediction': df1['query'],
    'db_id': df_final['db_id']
})

# %%
df_control['prediction'] = df_control['prediction'].str.replace('\n', ' ', regex=False)

# %%
df_control
# Out:
#                                            prediction                  db_id
# 0            SELECT COUNT(*) FROM head WHERE age > 56  department_management
# 1   SELECT head.name, head.born_state, head.age FR...  department_management
# 2   SELECT creation, name, budget in billions FROM...  department_management
# 3   SELECT MAX(`budget in billions`), MIN(`budget ...  department_management
# 4   SELECT AVG(`num employees`) FROM department WH...  department_management
# ..                                                ...                    ...
# 95  SELECT course_name FROM courses ORDER BY cours...     student_assessment
# 96  SELECT course_name FROM courses ORDER BY cours...     student_assessment
# 97  SELECT `first name` FROM people ORDER BY `firs...     student_assessment
# 98  SELECT `first name` FROM people ORDER BY `firs...     student_assessment
# 99  SELECT DISTINCT "student id" FROM "student cou...     student_assessment
#
# [100 rows x 2 columns]

# %%
df_text2sql = pd.DataFrame({
    'prediction': df2['final_query'],
    'db_id': df_final['db_id']
})
#df_text2sql['prediction'] = df_text2sql['prediction'].str.replace('\n', ' ', regex=False)

# %%
df_text2sql = df_text2sql.iloc[0:30]
df_text2sql
# Out:
#                                            prediction                  db_id
# 0           SELECT COUNT(*) FROM head WHERE age > 56;  department_management
# 1   SELECT head.name, head.born_state, head.age FR...  department_management
# 2   Corrected SQL Query: SELECT creation, name, `b...  department_management
# 3   SELECT MAX(`budget in billions`), MIN(`budget ...  department_management
# 4   SELECT AVG(`num employees`) FROM department WH...  department_management
# 5   SELECT name FROM head WHERE born_state != 'Cal...  department_management
# 6   SELECT DISTINCT department.creation \nFROM dep...  department_management
# 7   SELECT born_state FROM head GROUP BY born_stat...  department_management
# 8   SELECT creation, COUNT(*) FROM department GROU...  department_management
# 9   SELECT department.name, department.num_employe...  department_management
# 10                   SELECT COUNT(*) FROM management;  department_management
# 11  SELECT COUNT(*) FROM department WHERE departme...  department_management
# 12  SELECT DISTINCT head.age FROM head JOIN manage...  department_management
# 13  SELECT h.born_state \nFROM department d \nJOIN...  department_management
# 14  SELECT department.id, department.name, COUNT(m...  department_management
# 15  SELECT head.id, head.name FROM head WHERE head...  department_management
# 16                          SELECT COUNT(*) FROM farm                   farm
# 17                          SELECT COUNT(*) FROM farm                   farm
# 18  SELECT `total horses` FROM farm ORDER BY `tota...                   farm
# 19  SELECT `farm id`, SUM(`total horses`) FROM far...                   farm
# 20  SELECT hosts FROM farm_competition WHERE theme...                   farm
# 21  SELECT hosts FROM farm_competition WHERE theme...                   farm
# 22  SELECT theme, year FROM farm_competition ORDER...                   farm
# 23  SELECT theme FROM farm_competition ORDER BY ye...                   farm
# 24  SELECT AVG(`Working_Horses`) FROM farm WHERE `...                   farm
# 25  SELECT AVG(`Working_Horses`) FROM `farm` WHERE...                   farm
# 26             SELECT MAX(cows), MIN(cows) FROM farm;                   farm
# 27              SELECT MAX(cows), MIN(cows) FROM farm                   farm
# 28           SELECT COUNT(DISTINCT status) FROM city;                   farm
# 29            SELECT COUNT(DISTINCT status) FROM city                   farm

# %%
df_text2sql.to_csv("text2sql_fewshot.tsv", sep='\t', index=False, header=False)

# %%
df_control.to_csv("control.tsv", sep='\t', index=False, header=False)

# %%
print(df_control.iloc[28])
# Out:
# prediction    SELECT COUNT(DISTINCT status) FROM city
# db_id                                            farm
# Name: 28, dtype: object
