# %%
import pandas as pd

df = pd.read_csv("control_results.csv")
df
# Out:
#     query_id                                           question  \
# 0          0  How many heads of the departments are older th...
# 1          1  List the name, born state and age of the heads...
# 2          2  List the creation year, name and budget of eac...
# 3          3  What are the maximum and minimum budget of the...
# 4          4  What is the average number of employees of the...
# ..       ...                                                ...
# 95        95   List the names of courses in alphabetical order?
# 96        96  What are the names of the courses in alphabeti...
# 97        97  List the first names of people in alphabetical...
# 98        98  What are the first names of the people in alph...
# 99        99  What are the id of students who registered cou...
#
#                                                schema  \
# 0   {'column_names': [[-1, '*'], [0, 'department i...
# 1   {'column_names': [[-1, '*'], [0, 'department i...
# ...

# %%
df2 = pd.read_csv("text2sql_results.csv")
df2
# Out:
#      query_id                                           question  \
# 0           0  How many heads of the departments are older th...
# 1           1  List the name, born state and age of the heads...
# 2           0  How many heads of the departments are older th...
# 3           1  List the name, born state and age of the heads...
# 4           2  List the creation year, name and budget of eac...
# ..        ...                                                ...
# 97         95   List the names of courses in alphabetical order?
# 98         96  What are the names of the courses in alphabeti...
# 99         97  List the first names of people in alphabetical...
# 100        98  What are the first names of the people in alph...
# 101        99  What are the id of students who registered cou...
#
#                                                 schema  \
# 0    {'column_names': [[-1, '*'], [0, 'department i...
# 1    {'column_names': [[-1, '*'], [0, 'department i...
# ...

# %%
# Out:
# [nltk_data] Downloading package punkt to /Users/alvinalex/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True
